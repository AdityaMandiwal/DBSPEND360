# %% [markdown]
# # GCP Cloud Cost Explorer (Stub)
#
# Placeholder notebook for the GCP implementation of the cloud cost explorer ETL.
#
# GCP is declared as a supported platform in `server/config/config_loader.py` and
# `config/app.dev.config` (`[cloud] platform = GCP`), but no production ETL exists yet.
#
# When implementing, mirror the structure of `aws_cloud_cost_explorer_app.ipynb` and
# `azure_cloud_cost_explorer_app.ipynb`:
# - A `GCPCostClient` that talks to the GCP Billing / Cost Management APIs.
# - A `GCPCostReporterApp` class that classifies costs into compute/storage/network/other
#   using a `GCP_SERVICE_CATEGORIES` mapping analogous to `AWS_SERVICE_CATEGORIES` /
#   `AZURE_METER_CLASSIFICATION`.
# - Audit/error log writes tagged with `source_system='GCP_COST'` (see
#   `jobs/ddls/dbspend360_error_log.sql` and `jobs/ddls/dbspend360_audit_log.sql`).
# - Output written to `dbspend360_cloud_cost_explorer` so downstream joins are unchanged.

# %%
# %run ./utils_common

# %%
raise NotImplementedError(
  'GCP cloud cost explorer is not implemented yet. '
  'Set [cloud] platform = AWS or Azure in config/app.<env>.config '
  'and run the corresponding notebook (aws_cloud_cost_explorer_app or '
  'azure_cloud_cost_explorer_app) instead.'
)
